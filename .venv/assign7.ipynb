# %%
import numpy as np
import pandas as pd
from itertools import combinations

# %%
df=pd.read_csv('/Users/avyaahuja/Machine Learning/.venv/Grocery Products Purchase.csv')
df.head()
# Out:
#           Product 1            Product 2       Product 3  \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                  NaN             NaN
# 3         pip fruit               yogurt    cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                   Product 4 Product 5 Product 6 Product 7 Product 8 Product 9  \
# 0               ready soups       NaN       NaN       NaN       NaN       NaN
# 1                       NaN       NaN       NaN       NaN       NaN       NaN
# 2                       NaN       NaN       NaN       NaN       NaN       NaN
# 3              meat spreads       NaN       NaN       NaN       NaN       NaN
# 4  long life bakery product       NaN       NaN       NaN       NaN       NaN
#
#   Product 10  ... Product 23 Product 24 Product 25 Product 26 Product 27  \
# 0        NaN  ...        NaN        NaN        NaN        NaN        NaN
# ...

# %%
def c_support(item,transactions):
    count = sum([1 for t in transactions if set(item).issubset(set(t))])
    return count / len(transactions)

# %%
def c_confidence(support_dict,X,itemset):
    support_itemset = support_dict[itemset]
    support_X = support_dict[X]
    confidence = support_itemset / support_X if support_X > 0 else 0
    return confidence

# %%
def association(transactions, min_support=0.2, min_confidence=0.5):
    unique_items = set(item for t in transactions for item in t if item is not None)
    
    itemsets = []
    for size in range(1, len(unique_items) + 1): 
        itemsets.extend(list(combinations(unique_items, size)))
    
    support_dict = {}
    for item in itemsets:
        support = c_support(item, transactions)
        if support >= min_support:
            support_dict[frozenset(item)] = support
    

    rules = []
    for itemset in support_dict.keys():
        if len(itemset) > 1:  
            for Y in itemset:
                X = itemset - frozenset([Y])
                if len(X) > 0:
                    confidence=c_confidence(support_dict,X,itemset)
                    
                    if confidence >= min_confidence:
                        rules.append((f"{set(X)} -> {Y}", support_dict[itemset], confidence))


    
    return rules

# %%
transactions = df.apply(lambda row: [col for col in df.columns if row[col] == 1], axis=1).tolist()
print(transactions)
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [
# ...

# %%
thr_supp=0.3
thr_conf=0.3
rules = association(transactions, min_support=thr_supp, min_confidence=thr_conf)
for rule in rules:
    print(f"Rule: {rule[0]}, Support: {rule[1]:.2f}, Confidence: {rule[2]:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 thr_supp=0.0
#       2 thr_conf=0.0
# ----> 3 rules = association(df[1:], min_support=thr_supp, min_confidence=thr_conf)
#       4 for rule in rules:
#       5     print(f"Rule: {rule[0]}, Support: {rule[1]:.2f}, Confidence: {rule[2]:.2f}")
#
# Cell In[5], line 10, in association(transactions, min_support, min_confidence)
#       8 support_dict = {}
#       9 for item in itemsets:
# ---> 10     support = c_support(item, transactions)
#      11     if support >= min_support:
#      12         support_dict[frozenset(item)] = support
#
# Cell In[3], line 2, in c_support(item, transactions)
#       1 def c_support(item,transactions):
# ----> 2     count = sum([1 for t in transactions if set(item).issubset(set(t))])
#       3     return count / len(transactions)
#
# Cell In[3], line 2, in <listcomp>(.0)
# ...
